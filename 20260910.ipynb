# %% [markdown]
# <a href="https://colab.research.google.com/github/26403-sketch/10703/blob/main/20260910.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
str = 'hello PYTHON'

# %%
jumin = input('주민등록번호 입력: ')

print('년:20 = jumin[0:2] = 년')
print
print
# Out:
# 주민등록번호 입력: 10
# 년:20 = jumin[0:2] = 년
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
a = input('평문 입력: ')
b = a[::-1]
c = b.replace('e','3').replace('a','4').replace('d','6').replace('h','7')
print('암호문'+c)
# Out:
# 평문 입력: asdf
# 암호문f6s4
