# %% [markdown]
# <a href="https://colab.research.google.com/github/26403-sketch/10703/blob/main/20260907.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import datetime
from datetime import datetime, date, time

# %%
print('<디데이(D-day) 프로그램>')
print()
year = int(input('연도를 입력하세요: '))
month = int(input('월을 입력하세요: '))
day = int(input('일을 입력하세요: '))
dt4 = date(year , month, day)
today = date.today()
dday = (dt4 - today).days
print(f'{year}년 {month}월 {day}일은 {dday}일 남았습니다.')
# Out:
# <디데이(D-day) 프로그램>
#
# 연도를 입력하세요: 2026
# 월을 입력하세요: 9
# 일을 입력하세요: 7
# 2026년 9월 7일은 0일 남았습니다.
