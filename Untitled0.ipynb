# %% [markdown]
# <a href="https://colab.research.google.com/github/26403-sketch/10703/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('=====회전 초밥 영수증=====')
print('  접시  단가  개수  합계')
print('빨간색 1,000  2   2,000')
print('노란색 2,000  3   6,000')
print('파란색 3,000  1   3,000')
print('초록색 4,000  2   8,000')
print('총 가격          19,000')
print('=========================')
# Out:
# =====회전 초밥 영수증=====
#   접시  단가  개수  합계
# 빨간색 1,000  2   2,000
# 노란색 2,000  3   6,000
# 파란색 3,000  1   3,000
# 초록색 4,000  2   8,000
# 총 가격          19,000
# ...
